# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q kss > /dev/null 2>&1

# %%
# !pip install huggingface_hub[hf_xet]

# %%
import sys
sys.path.append('/content/drive/MyDrive/emotion_project')

from train_sub import train_sub
train(start_epoch=0, total_epochs=10)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/289 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/425 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/495k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# WARNING:root:Oh! You have mecab in your environment. Kss will take this as a backend! :D
# model.safetensors:   0%|          | 0.00/445M [00:00<?, ?B/s]
# ...

# %%
import sys
sys.path.append('/content/drive/MyDrive/emotion_project')

from train_major import train_major
train2(start_epoch=0, total_epochs=10)
# Out:
# Epoch 1: 100%|██████████| 10740/10740 [09:13<00:00, 19.42it/s, loss=1.98]
# ✅ Epoch 1, Train Loss: 1.4301
# 📊 Val Accuracy: 0.4367, Micro F1: 0.4367, Macro F1: 0.4432
# ✅ Best model updated!
# Epoch 2: 100%|██████████| 10740/10740 [09:14<00:00, 19.38it/s, loss=0.86]
# ✅ Epoch 2, Train Loss: 1.3106
# 📊 Val Accuracy: 0.4464, Micro F1: 0.4464, Macro F1: 0.4580
# ✅ Best model updated!
# Epoch 3: 100%|██████████| 10740/10740 [09:14<00:00, 19.38it/s, loss=1.2]
# ✅ Epoch 3, Train Loss: 1.1963
# 📊 Val Accuracy: 0.4506, Micro F1: 0.4506, Macro F1: 0.4649
# ✅ Best model updated!
# Epoch 4: 100%|██████████| 10740/10740 [09:15<00:00, 19.35it/s, loss=1.35]
# ✅ Epoch 4, Train Loss: 1.0564
# 📊 Val Accuracy: 0.4441, Micro F1: 0.4441, Macro F1: 0.4600
# Epoch 5: 100%|██████████| 10740/10740 [09:12<00:00, 19.44it/s, loss=0.953]
# ✅ Epoch 5, Train Loss: 0.9058
# 📊 Val Accuracy: 0.4423, Micro F1: 0.4423, Macro F1: 0.4601
# Epoch 6: 100%|██████████| 10740/10740 [09:12<00:00, 19.45it/s, loss=1.13]
# ...

# %%
import sys
sys.path.append('/content/drive/MyDrive/emotion_project')

from evaluate import evaluate
evaluate()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/289 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/425 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/495k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# WARNING:root:Oh! You have mecab in your environment. Kss will take this as a backend! :D
# model.safetensors:   0%|          | 0.00/445M [00:00<?, ?B/s]
# ...

# %%
import sys
sys.path.append('/content/drive/MyDrive/emotion_project')

from predict import predict
predict3("왜 먹지를 못하니, 운수가 좋더니만...")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/289 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/425 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/495k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Text(value='', description='문장:')
# Output()
# 📝 입력 문장: 왜 먹지를 못하니, 운수가 좋더니만...
# 🎯 필터링 된 감정:
# ...
